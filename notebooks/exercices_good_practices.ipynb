# %% [markdown]
# # Data Analysis and Data Science
# ## Putting it all together
#
# By: Caroline Labelle
# <br>For: BIM6065-C
#
# <br>
# Date: July 8th, 2024
#
# <hr style="border:1px solid black"> </hr>

# %%
### Student Name: 
print("Léna FABRE")
# Out:
# Léna FABRE

# %% [markdown]
# Complete the following exercises and push your notebook on Github: submit your Github handle on StudiUM.
#
# In a terminal :
#
# 1. Go in the same directory as your notebook: `cd path_to_your_notebook/`
# 2. Commit the change made to your notebook: `git commit -am "add_your_personalized_note"`
# 3. Push your commit on Github: `git push origin main`
#
# Go to Github and double check that the pushed Notebook is the version you want to hand in.

# %%
### Import sklearn
import sklearn.decomposition, sklearn.cluster

### Import scipy
import scipy as sp

### Import pandas, numpy, seaborn and matplotlib.pyplot
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(10, 6)})
sns.set_theme(context="notebook", style="white")

# %% [markdown]
# # Breast Cancer Subtypes Analysis [50 pts]
#
# You are given a gene expression dataset of $N$ breast cancer patients with their clinical subtype. You wish to know if you can assess the clinical subtypes based on the gene expression. To do so you will be using various methods presented through out the class.

# %% [markdown]
# ## Import the data [10 pts]
#
# Your dataset concist of three files:
# 1. `genes_id.txt`
# 2. `patient_subtype.txt`
# 3. `patient_expression.txt`.
#
# Import the various files and build your dataset daframe. You should have for each patient her/his gene expression profil and clinical subtypes. Use the gene IDs as identifier for the columns or row names (you choose how to build your dataframe).

# %% [markdown]
# ### Import the files individually [3 pts]

# %%
genes_id = pd.read_csv("/u/fabrelen/code_github/datasets/genes_id.txt", header=None)
patient_subtype = pd.read_csv("/u/fabrelen/code_github/datasets/patient_subtype.txt", header=None)
patient_expression = pd.read_csv("/u/fabrelen/code_github/datasets/patient_expression.txt", sep=" ", header=None)

# %%
#patient_subtype.head()
patient_expression.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.326515  3.475678  2.374959  3.409941  0.014148  3.235387  0.094595
# 1  1.885133  2.752910  3.770004  3.822052  0.051402  3.001023  0.241303
# 2  3.246316  4.423018  3.700385  4.369893  0.155187  3.752491  0.102125
# 3  2.161512  2.314358  3.562899  3.786747  0.039245  4.227823  0.493791
# 4  2.795468  1.876752  0.658127  2.581386  0.014486  2.688765  0.432283
#
#          7         8         9   ...        37        38        39        40  \
# 0  4.488874  2.023978  3.996567  ...  0.415417  3.163366  1.751804  1.727270
# 1  3.680198  1.820556  1.344271  ...  2.035764  2.339897  0.949565  1.967062
# 2  3.779098  2.218593  1.927426  ...  1.123048  3.647681  1.063245  2.876544
# 3  4.124650  2.202475  2.317170  ...  0.930984  3.071066  0.577870  2.554480
# 4  2.655957  1.872897  0.924654  ...  1.975961  2.893713  0.272402  2.119050
#
#          41        42        43        44        45        46
# 0  4.541346  3.437507  5.678637  7.451924  0.598057  2.860720
# 1  4.167635  3.288760  5.370061  2.870596  0.102755  3.075090
# 2  4.498677  2.722251  3.125330  1.928449  0.374845  2.531836
# 3  4.879861  3.597988  5.953152  3.761062  0.528845  1.604472
# 4  3.571224  2.554718  0.189085  0.000000  0.199501  0.041927
#
# [5 rows x 47 columns]

# %% [markdown]
# ### How many patient are you considering? [1 pt]

# %%
print(len(patient_expression), "patients")
# Out:
# 645 patients

# %% [markdown]
# ### How many genes are you considering? [1 pt]

# %%
print(len(genes_id),"gènes")
# Out:
# 47 gènes

# %% [markdown]
# ### Combine the data from all three files into one dataframe [5 pts]
# You can use one of the dataframe as the 'main' one, and then rename its columns and add a new column.
#
# **Show a preview/overview of your dataframe**

# %%
expression = patient_expression.copy()
expression.columns= genes_id[0]
expression.loc[:,"patient_subtype"] = patient_subtype.iloc[:,0]

expression
# Out:
# 0    ENSG00000011426.9  ENSG00000054598.6  ENSG00000062038.12  \
# 0             1.326515           3.475678            2.374959
# 1             1.885133           2.752910            3.770004
# 2             3.246316           4.423018            3.700385
# 3             2.161512           2.314358            3.562899
# 4             2.795468           1.876752            0.658127
# ..                 ...                ...                 ...
# 640           0.820838           2.418684            3.460263
# 641           1.666605           1.818016            2.965531
# 642           0.810583           2.097097            3.595351
# 643           1.153391           0.935530            2.415240
# 644           1.980530           1.754886            2.231407
#
# 0    ENSG00000077152.8  ENSG00000082175.13  ENSG00000089685.13  \
# 0             3.409941            0.014148            3.235387
# 1             3.822052            0.051402            3.001023
# 2             4.369893            0.155187            3.752491
# 3             3.786747            0.039245            4.227823
# 4             2.581386            0.014486            2.688765
# ..                 ...                 ...                 ...
# 640           1.714065            2.574779            1.158088
# 641           3.398361            1.131149            2.243665
# 642           1.667315            0.563232            1.041924
# 643           2.179527            0.183943            1.688365
# 644           3.266043            1.223170            2.812263
#
# 0    ENSG00000091831.20  ENSG00000092621.10  ENSG00000094804.8  \
# 0              0.094595            4.488874           2.023978
# 1              0.241303            3.680198           1.820556
# 2              0.102125            3.779098           2.218593
# 3              0.493791            4.124650           2.202475
# 4              0.432283            2.655957           1.872897
# ..                  ...                 ...                ...
# 640            2.099645            2.689138           0.705885
# 641            2.103245            3.090764           1.380203
# 642            1.894974            1.950360           1.017512
# 643            0.297845            2.814779           0.754930
# 644            2.358093            2.448979           1.666034
#
# 0    ENSG00000099953.8  ...  ENSG00000171848.12  ENSG00000173890.15  \
# 0             3.996567  ...            3.163366            1.751804
# 1             1.344271  ...            2.339897            0.949565
# 2             1.927426  ...            3.647681            1.063245
# 3             2.317170  ...            3.071066            0.577870
# 4             0.924654  ...            2.893713            0.272402
# ..                 ...  ...                 ...                 ...
# 640           3.340791  ...            1.112896            2.147804
# 641           4.770786  ...            2.517961            1.820856
# 642           3.408128  ...            1.019320            1.837105
# 643           4.585375  ...            2.377948            2.120787
# 644           3.623672  ...            2.063080            2.663586
#
# 0    ENSG00000174371.15  ENSG00000175063.15  ENSG00000176890.14  \
# 0              1.727270            4.541346            3.437507
# 1              1.967062            4.167635            3.288760
# 2              2.876544            4.498677            2.722251
# 3              2.554480            4.879861            3.597988
# 4              2.119050            3.571224            2.554718
# ..                  ...                 ...                 ...
# 640            0.498596            1.633678            1.791459
# 641            1.147327            3.336830            2.926771
# 642            0.575619            1.638372            1.749170
# 643            0.626063            2.161975            1.224772
# 644            1.524862            3.562984            3.199560
#
# 0    ENSG00000186081.10  ENSG00000186847.5  ENSG00000186868.14  \
# 0              5.678637           7.451924            0.598057
# 1              5.370061           2.870596            0.102755
# 2              3.125330           1.928449            0.374845
# 3              5.953152           3.761062            0.528845
# 4              0.189085           0.000000            0.199501
# ..                  ...                ...                 ...
# 640            5.193883           5.470001            2.507121
# 641            4.834529           5.614588            1.520555
# 642            5.413128           5.591127            2.129137
# 643            3.553468           3.305371            1.386436
# 644            4.089408           4.844924            2.032381
#
# 0    ENSG00000261857.5  patient_subtype
# 0             2.860720            Basal
# 1             3.075090            Basal
# 2             2.531836            Basal
# 3             1.604472            Basal
# 4             0.041927            Basal
# ..                 ...              ...
# 640           2.424799           Normal
# 641           2.128657           Normal
# 642           1.244375           Normal
# 643           0.515823           Normal
# 644           1.039759           Normal
#
# [645 rows x 48 columns]

# %% [markdown]
# ## Explore the dataset [15 pts]

# %% [markdown]
# ### How many subtypes are you considering? [1 pts]

# %%
expression.loc[:,"patient_subtype"].nunique()
print(expression.loc[:,"patient_subtype"].nunique(), "subtypes")
# Out:
# 5 subtypes

# %% [markdown]
# ### How many patients are associtated to each subtype? [2 pts]

# %%
print(expression["patient_subtype"].value_counts())
print("Il y a donc 191 patients associés au sous type basal, 82 à Her2, 179 à LumA, 165 à LumB et 28 à normal")
# Out:
# patient_subtype
# Basal     191
# LumA      179
# LumB      165
# Her2       82
# Normal     28
# Name: count, dtype: int64
# Il y a donc 191 patients associés au sous type basal, 82 à Her2, 179 à LumA, 165 à LumB et 28 à normal

# %% [markdown]
# ### Generate a graph showing the distribution of the average expression of each gene [5 pts]

# %%
expression = patient_expression.copy()
expression.columns= genes_id[0]
expression.loc[:,"patient_subtype"] = patient_subtype.iloc[:,0]

mean_expression = expression.drop(columns=["patient_subtype"]).mean()
mean_expression_df = pd.DataFrame()
mean_expression_df["gene_id"] = mean_expression.index
mean_expression_df["mean_expression"] = mean_expression.values
#print(mean_expression_df)

p = sns.barplot(data=mean_expression_df, x="gene_id", y="mean_expression")
plt.xticks(rotation=90)
p.set_title("Distribution de l'expression moyenne de chaque gène")
sns.despine()

# %% [markdown]
# ### What are the two genes with the largest standard deviation for all patient? [2 pts]
# To answer this question, you can use the `df.std()` and `df.sort_values()`. You can look into the doc for more informations on these two functions.
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.std.html
# 2. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html#pandas.DataFrame.sort_values

# %%
expression = patient_expression.copy()
expression.columns = genes_id[0]

gene_std = expression.std()
sorted_gene_std = gene_std.sort_values(ascending=False)
top_two_genes = sorted_gene_std.head(2)

print("Les deux gènes avec le plus grand écart type sont:")
print(top_two_genes)
# Out:
# Les deux gènes avec le plus grand écart type sont:
# 0
# ENSG00000186081.10    1.899352
# ENSG00000128422.14    1.880477
# dtype: float64

# %% [markdown]
# ### Compare the expression of these two genes: are they corrolated based on tumor subtypes? [5 pts]
# The two genes to consider are **ENSG00000186081.10** and **ENSG00000128422.14**.
#
# To answer this question:
# 1. Make a figure showing the correlation between the two genes by clinical subtypes,
# 2. Calculate a correlation coefficient for each comparison and,
# 3. Briefly interpret your results (make sure your interpretation is consistent with the correlation coefficient used).

# %%
expression.columns.values
# Out:
# array(['ENSG00000011426.9', 'ENSG00000054598.6', 'ENSG00000062038.12',
#        'ENSG00000077152.8', 'ENSG00000082175.13', 'ENSG00000089685.13',
#        'ENSG00000091831.20', 'ENSG00000092621.10', 'ENSG00000094804.8',
#        'ENSG00000099953.8', 'ENSG00000101057.14', 'ENSG00000104332.10',
#        'ENSG00000105173.12', 'ENSG00000106605.9', 'ENSG00000107262.15',
#        'ENSG00000115648.12', 'ENSG00000117399.12', 'ENSG00000117724.11',
#        'ENSG00000128422.14', 'ENSG00000129514.5', 'ENSG00000133627.16',
#        'ENSG00000134057.13', 'ENSG00000135679.20', 'ENSG00000136997.13',
#        'ENSG00000138180.14', 'ENSG00000141424.11', 'ENSG00000141736.12',
#        'ENSG00000141738.12', 'ENSG00000142945.11', 'ENSG00000146648.14',
#        'ENSG00000148773.11', 'ENSG00000151715.6', 'ENSG00000160867.13',
#        'ENSG00000164611.11', 'ENSG00000165304.6', 'ENSG00000171428.12',
#        'ENSG00000171604.10', 'ENSG00000171791.11', 'ENSG00000171848.12',
#        'ENSG00000173890.15', 'ENSG00000174371.15', 'ENSG00000175063.15',
#        'ENSG00000176890.14', 'ENSG00000186081.10', 'ENSG00000186847.5',
#        'ENSG00000186868.14', 'ENSG00000261857.5'], dtype=object)

# %%
expression = patient_expression.copy()
expression.columns= genes_id[0]
expression.loc[:,"patient_subtype"] = patient_subtype.iloc[:,0]

correl = expression.loc[:, ["ENSG00000186081.10", "ENSG00000128422.14", "patient_subtype"]]
correl
correl.iloc[:, 1]
# Out:
# 0      5.560600
# 1      4.021198
# 2      2.577910
# 3      4.104817
# 4      0.216795
#          ...
# 640    5.109304
# 641    4.642594
# 642    5.072863
# 643    4.039306
# 644    4.298240
# Name: ENSG00000128422.14, Length: 645, dtype: float64

# %%
sns.lmplot(data=correl, x="ENSG00000186081.10", y="ENSG00000128422.14", hue = "patient_subtype", col = "patient_subtype")

# %%
Basal = expression.loc[expression.patient_subtype == "Basal", ["ENSG00000186081.10", "ENSG00000128422.14"]]
LumA = expression.loc[expression.patient_subtype == "LumA", ["ENSG00000186081.10", "ENSG00000128422.14"]]
LumB = expression.loc[expression.patient_subtype == "LumB", ["ENSG00000186081.10", "ENSG00000128422.14"]]
Her2 = expression.loc[expression.patient_subtype == "Her2", ["ENSG00000186081.10", "ENSG00000128422.14"]]
Normal = expression.loc[expression.patient_subtype == "Normal", ["ENSG00000186081.10", "ENSG00000128422.14"]]

Basal_reg = sp.stats.linregress(Basal["ENSG00000186081.10"], Basal["ENSG00000128422.14"])
print("Basal:", Basal_reg.rvalue)
LumA_reg = sp.stats.linregress(LumA["ENSG00000186081.10"], LumA["ENSG00000128422.14"])
print("LumA:", LumA_reg.rvalue)
LumB_reg = sp.stats.linregress(LumB["ENSG00000186081.10"], LumB["ENSG00000128422.14"])
print("LumB:", LumB_reg.rvalue)
Her2_reg = sp.stats.linregress(Her2["ENSG00000186081.10"], Her2["ENSG00000128422.14"])
print("Her2:", Her2_reg.rvalue)
Normal_reg = sp.stats.linregress(Normal["ENSG00000186081.10"], Normal["ENSG00000128422.14"])
print("Normal:", Normal_reg.rvalue)

print("Les coefficients de Pearson sont les plus élevés pour les soustypes lum A et B ainsi que pour Her2. Il semble ainsi que l'expression des deux gènes étudiés suivent une corrélation linéaire pour ces soustypes. Pour les types Basal et Normal, les coefficients sont trop bas pour que l'on puisse conclure à une corrélation linéaire entre les deux gènes, on pourrait cependant calculer le coefficient de Spearman pour le déterminer la monotonie de la relation.")
# Out:
# Basal: 0.5544196989003722
# LumA: 0.8914287604819622
# LumB: 0.8974230320693612
# Her2: 0.7362528192401565
# Normal: 0.5350817650187477
# Les coefficients de Pearson sont les plus élevés pour les soustypes lum A et B ainsi que pour Her2. Il semble ainsi que l'expression des deux gènes étudiés suivent une corrélation linéaire pour ces soustypes. Pour les types Basal et Normal, les coefficients sont trop bas pour que l'on puisse conclure à une corrélation linéaire entre les deux gènes, on pourrait cependant calculer le coefficient de Spearman pour le déterminer la monotonie de la relation.

# %% [markdown]
# ## Clustering [25 pts]
# You are wondering if the M genes considered by your dataset are enough to cluster the N patients by their cancer subtype. To answer this question, you first want to apply a dimensionality reduction algorithm to your dataset. You then want to apply a clustering alogirthme to the reduced components, and compare the clustering labels to the clinical subtype of each patient.

# %% [markdown]
# ### Apply a PCA Dimensionality reduction to your gene expression dataset [4 pts]
#
# Once you selected the numerical gene expression, scale the value and initiate a PCA object. You want to reduce your set of features to **25 components**.

# %%
expression
# Out:
# 0    ENSG00000011426.9  ENSG00000054598.6  ENSG00000062038.12  \
# 0             1.326515           3.475678            2.374959
# 1             1.885133           2.752910            3.770004
# 2             3.246316           4.423018            3.700385
# 3             2.161512           2.314358            3.562899
# 4             2.795468           1.876752            0.658127
# ..                 ...                ...                 ...
# 640           0.820838           2.418684            3.460263
# 641           1.666605           1.818016            2.965531
# 642           0.810583           2.097097            3.595351
# 643           1.153391           0.935530            2.415240
# 644           1.980530           1.754886            2.231407
#
# 0    ENSG00000077152.8  ENSG00000082175.13  ENSG00000089685.13  \
# 0             3.409941            0.014148            3.235387
# 1             3.822052            0.051402            3.001023
# 2             4.369893            0.155187            3.752491
# 3             3.786747            0.039245            4.227823
# 4             2.581386            0.014486            2.688765
# ..                 ...                 ...                 ...
# 640           1.714065            2.574779            1.158088
# 641           3.398361            1.131149            2.243665
# 642           1.667315            0.563232            1.041924
# 643           2.179527            0.183943            1.688365
# 644           3.266043            1.223170            2.812263
#
# 0    ENSG00000091831.20  ENSG00000092621.10  ENSG00000094804.8  \
# 0              0.094595            4.488874           2.023978
# 1              0.241303            3.680198           1.820556
# 2              0.102125            3.779098           2.218593
# 3              0.493791            4.124650           2.202475
# 4              0.432283            2.655957           1.872897
# ..                  ...                 ...                ...
# 640            2.099645            2.689138           0.705885
# 641            2.103245            3.090764           1.380203
# 642            1.894974            1.950360           1.017512
# 643            0.297845            2.814779           0.754930
# 644            2.358093            2.448979           1.666034
#
# 0    ENSG00000099953.8  ...  ENSG00000171848.12  ENSG00000173890.15  \
# 0             3.996567  ...            3.163366            1.751804
# 1             1.344271  ...            2.339897            0.949565
# 2             1.927426  ...            3.647681            1.063245
# 3             2.317170  ...            3.071066            0.577870
# 4             0.924654  ...            2.893713            0.272402
# ..                 ...  ...                 ...                 ...
# 640           3.340791  ...            1.112896            2.147804
# 641           4.770786  ...            2.517961            1.820856
# 642           3.408128  ...            1.019320            1.837105
# 643           4.585375  ...            2.377948            2.120787
# 644           3.623672  ...            2.063080            2.663586
#
# 0    ENSG00000174371.15  ENSG00000175063.15  ENSG00000176890.14  \
# 0              1.727270            4.541346            3.437507
# 1              1.967062            4.167635            3.288760
# 2              2.876544            4.498677            2.722251
# 3              2.554480            4.879861            3.597988
# 4              2.119050            3.571224            2.554718
# ..                  ...                 ...                 ...
# 640            0.498596            1.633678            1.791459
# 641            1.147327            3.336830            2.926771
# 642            0.575619            1.638372            1.749170
# 643            0.626063            2.161975            1.224772
# 644            1.524862            3.562984            3.199560
#
# 0    ENSG00000186081.10  ENSG00000186847.5  ENSG00000186868.14  \
# 0              5.678637           7.451924            0.598057
# 1              5.370061           2.870596            0.102755
# 2              3.125330           1.928449            0.374845
# 3              5.953152           3.761062            0.528845
# 4              0.189085           0.000000            0.199501
# ..                  ...                ...                 ...
# 640            5.193883           5.470001            2.507121
# 641            4.834529           5.614588            1.520555
# 642            5.413128           5.591127            2.129137
# 643            3.553468           3.305371            1.386436
# 644            4.089408           4.844924            2.032381
#
# 0    ENSG00000261857.5  patient_subtype
# 0             2.860720            Basal
# 1             3.075090            Basal
# 2             2.531836            Basal
# 3             1.604472            Basal
# 4             0.041927            Basal
# ..                 ...              ...
# 640           2.424799           Normal
# 641           2.128657           Normal
# 642           1.244375           Normal
# 643           0.515823           Normal
# 644           1.039759           Normal
#
# [645 rows x 48 columns]

# %%
subset_PCA = expression.iloc[:,0:25]
subset_PCA.head()
# Out:
# 0  ENSG00000011426.9  ENSG00000054598.6  ENSG00000062038.12  \
# 0           1.326515           3.475678            2.374959
# 1           1.885133           2.752910            3.770004
# 2           3.246316           4.423018            3.700385
# 3           2.161512           2.314358            3.562899
# 4           2.795468           1.876752            0.658127
#
# 0  ENSG00000077152.8  ENSG00000082175.13  ENSG00000089685.13  \
# 0           3.409941            0.014148            3.235387
# 1           3.822052            0.051402            3.001023
# 2           4.369893            0.155187            3.752491
# 3           3.786747            0.039245            4.227823
# 4           2.581386            0.014486            2.688765
#
# 0  ENSG00000091831.20  ENSG00000092621.10  ENSG00000094804.8  \
# 0            0.094595            4.488874           2.023978
# 1            0.241303            3.680198           1.820556
# 2            0.102125            3.779098           2.218593
# 3            0.493791            4.124650           2.202475
# 4            0.432283            2.655957           1.872897
#
# 0  ENSG00000099953.8  ...  ENSG00000115648.12  ENSG00000117399.12  \
# 0           3.996567  ...            1.247502            4.026396
# 1           1.344271  ...            0.273573            4.176842
# 2           1.927426  ...            0.436753            4.304707
# 3           2.317170  ...            1.028851            4.511984
# 4           0.924654  ...            0.176638            2.636100
#
# 0  ENSG00000117724.11  ENSG00000128422.14  ENSG00000129514.5  \
# 0            2.031909            5.560600           0.078954
# 1            2.584068            4.021198           0.795911
# 2            3.400007            2.577910           0.945022
# 3            2.486453            4.104817           0.196359
# 4            3.627018            0.216795           0.213796
#
# 0  ENSG00000133627.16  ENSG00000134057.13  ENSG00000135679.20  \
# 0            0.076636            3.472385            1.738914
# 1            2.129904            2.820209            1.808738
# 2            2.097359            3.767037            1.786205
# 3            1.372190            3.896626            1.731629
# 4            1.042112            2.935611            2.437925
#
# 0  ENSG00000136997.13  ENSG00000138180.14
# 0            5.060550            2.085367
# 1            4.050674            2.936971
# 2            5.033092            3.502582
# 3            4.626012            2.934217
# 4            3.747512            1.833769
#
# [5 rows x 25 columns]

# %%
scaler = sklearn.preprocessing.StandardScaler()
subset_scaled = scaler.fit_transform(subset_PCA)

pca = sklearn.decomposition.PCA(n_components=25)
pca.fit(subset_scaled)
# Out:
# PCA(n_components=25)

# %% [markdown]
# ### What percentage of the variance of the dataset is explained by the two first component? [2 pt]

# %%
explained_variance = pca.explained_variance_ratio_
variance = (explained_variance[0] + explained_variance[1])*100

print(variance,"pourcent")
# Out:
# 60.86797918260155 pourcent

# %% [markdown]
# ### Apply the PCA onto your gene expression data and create a DataFrame with the PCs and the clinical patient subtypes [4 pts]
# **Show a preview/overview of your dataframe**

# %%
patient_subtype_values= patient_subtype.values.flatten()
pca_reduce = pca.fit_transform(subset_scaled)
pca_reduce

data_reduce = pd.DataFrame(pca_reduce)
data_reduce.loc[:, "patient_subtypes"] = patient_subtype_values

data_reduce.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  3.191776 -1.269262  0.269585  3.104386  1.154152  1.863135 -1.154988
# 1  4.237853 -2.035199 -1.038591  0.756140 -1.075370  0.128364  0.477950
# 2  6.288340 -0.565002 -2.000904  0.381878 -0.080502 -0.366138  0.079425
# 3  4.926959  0.122601 -0.519310  2.107137 -0.155072  0.807192 -0.002299
# 4  1.850317 -1.395755 -1.703404 -3.273604 -1.632079 -0.428229 -0.572342
#
#           7         8         9  ...        16        17        18        19  \
# 0  0.381951  0.834659  0.784531  ...  0.380751 -0.168810 -0.978283  1.029806
# 1 -0.299746  0.295559 -0.204188  ... -0.221070  0.143611 -0.632339  0.248902
# 2  0.166639 -0.182792 -0.683557  ... -0.114111  0.138149 -0.153199 -0.322682
# 3  0.118968  0.874198 -0.170332  ... -0.281658  0.080779 -0.346825  0.208456
# 4  2.053054  0.115451 -0.913757  ... -0.223190 -0.287280 -0.005660  0.295042
#
#          20        21        22        23        24  patient_subtypes
# 0 -0.153584  0.245063 -0.357822  0.073876 -0.074982             Basal
# 1  0.548888  0.320179 -0.223276  0.856670  0.095788             Basal
# 2  0.306371 -0.473021  0.478808 -0.066732  0.256143             Basal
# 3  0.187001  0.235108 -0.401767 -0.164023 -0.394653             Basal
# 4 -0.086798  1.349678 -0.906197 -0.524489 -0.281427             Basal
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Plot a figure showing the two first PCs and color the samples by their clinical subtype [3 pts]
# Do you think the k-means algorithm will be able to accurately cluster patients based on their clinical subtype? Why?

# %%
sns.scatterplot(x=data_reduce[0], y=data_reduce[1], hue=data_reduce["patient_subtypes"])
plt.title("Distribution of the two first PCs")
print("l'algorithme k-means est capable de regrouper les patients selon leur soustype clinique, puisqu'on observe ci dessous 5 clusters distincts")
# Out:
# l'algorithme k-means est capable de regrouper les patients selon leur soustype clinique, puisqu'on observe ci dessous 5 clusters distincts

# %% [markdown]
# ### Apply the K-means algorithme to your reduced dataset [5 pts]
# When applying the K-means, you should use all 25 PCs, generated by your PCA. Add the k-means labels to your reduced dataset.

# %%
import pandas as pd
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, random_state=25)
kmeans.fit(data_reduce.iloc[:, :25])
data_reduce['kmeans_labels'] = kmeans.labels_
result_table = pd.DataFrame(data_reduce.iloc[:, :25])
result_table['kmeans_labels'] = data_reduce['kmeans_labels']
result_table['patient_subtypes'] = data_reduce['patient_subtypes']
result_table
# Out:
#             0         1         2         3         4         5         6  \
# 0    3.191776 -1.269262  0.269585  3.104386  1.154152  1.863135 -1.154988
# 1    4.237853 -2.035199 -1.038591  0.756140 -1.075370  0.128364  0.477950
# 2    6.288340 -0.565002 -2.000904  0.381878 -0.080502 -0.366138  0.079425
# 3    4.926959  0.122601 -0.519310  2.107137 -0.155072  0.807192 -0.002299
# 4    1.850317 -1.395755 -1.703404 -3.273604 -1.632079 -0.428229 -0.572342
# ..        ...       ...       ...       ...       ...       ...       ...
# 640 -2.835265 -4.712691  0.522505  0.514583  0.985885  1.041204  1.286377
# 641  0.127821 -1.164112  1.469940  1.316113  0.762263  0.082247  0.344506
# 642 -2.716939 -4.974252  0.736705  0.246242  0.713455  0.961331 -0.348982
# 643 -1.925909 -2.932096  2.755833  0.413863 -0.050684  0.717084  0.068399
# 644 -0.023126 -0.863140  0.390850  0.003830  0.589720  0.360695  0.231580
#
#             7         8         9  ...        17        18        19  \
# 0    0.381951  0.834659  0.784531  ... -0.168810 -0.978283  1.029806
# 1   -0.299746  0.295559 -0.204188  ...  0.143611 -0.632339  0.248902
# 2    0.166639 -0.182792 -0.683557  ...  0.138149 -0.153199 -0.322682
# 3    0.118968  0.874198 -0.170332  ...  0.080779 -0.346825  0.208456
# 4    2.053054  0.115451 -0.913757  ... -0.287280 -0.005660  0.295042
# ..        ...       ...       ...  ...       ...       ...       ...
# 640 -0.097345  0.348508  0.634501  ... -0.372073  0.043589 -0.058170
# 641 -0.344068 -0.156712  0.614144  ... -0.095989  0.150549  0.004769
# 642  1.107312  0.316669  0.709176  ...  0.029118 -0.150162 -0.234500
# 643  0.872445  0.780126 -0.158671  ... -0.698067  0.312720  0.118517
# 644  0.548320  0.031272  0.383957  ... -0.221521 -0.942778 -0.505068
#
#            20        21        22        23        24  kmeans_labels  \
# 0   -0.153584  0.245063 -0.357822  0.073876 -0.074982              1
# 1    0.548888  0.320179 -0.223276  0.856670  0.095788              1
# 2    0.306371 -0.473021  0.478808 -0.066732  0.256143              1
# 3    0.187001  0.235108 -0.401767 -0.164023 -0.394653              1
# 4   -0.086798  1.349678 -0.906197 -0.524489 -0.281427              1
# ..        ...       ...       ...       ...       ...            ...
# 640 -0.121964 -0.302049  0.579673 -0.368864 -0.151074              3
# 641 -0.335633 -0.124911  0.309808  0.680409  0.096925              0
# 642  0.149139 -0.263531  0.195323 -0.322832 -0.218346              3
# 643  0.017319  0.030572  0.246833  0.437510 -0.116004              3
# 644  0.307751 -0.451584  0.187078  0.426835 -0.182916              0
#
#      patient_subtypes
# 0               Basal
# 1               Basal
# 2               Basal
# 3               Basal
# 4               Basal
# ..                ...
# 640            Normal
# 641            Normal
# 642            Normal
# 643            Normal
# 644            Normal
#
# [645 rows x 27 columns]

# %% [markdown]
# ### What value of k did you use and why? [2 pt]

# %%
print("J'ai utilisé une valeur de k=5 car il existe 5 sous-types de cancer et on nous a demandé de regrouper les patients en fonction de leur sous-type de cancer.")
# Out:
# J'ai utilisé une valeur de k=5 car il existe 5 sous-types de cancer et on nous a demandé de regrouper les patients en fonction de leur sous-type de cancer.

# %% [markdown]
# ### Compare your k-means labels to the clinical substypes [5 pts]
# You comparison can by qualitative and/or quantitative.
#
# **Are you able to cluster patient by clinical substypes from your subset of gene expressions? Briefly describe and interpret your results.**

# %%
sns.countplot(x="kmeans_labels", hue="patient_subtypes", data=result_table)
plt.title("Comparison K-means labels vs. clinical subtypes")
sns.despine()

# %%
#interpretation
print("On observe un clustering efficace pour les sous types Basal (cluster 1) et LumB (cluster 2). Par contre les autres sous types LumA, Her 2 et Normal ne sont pas biens séparés et sont présents dans plusieurs clusters. Ainsi, les clusters K-means ne sont pas capables de capturer avec precision toutes les différences entre les sous-types cliniques")
# Out:
# On observe un clustering efficace pour les sous types Basal (cluster 1) et LumB (cluster 2). Par contre les autres sous types LumA, Her 2 et Normal ne sont pas biens séparés et sont présents dans plusieurs clusters. Ainsi, les clusters K-means ne sont pas capables de capturer avec precision toutes les différences entre les sous-types cliniques
